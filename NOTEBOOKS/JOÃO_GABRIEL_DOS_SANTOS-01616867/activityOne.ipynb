# %%
valores = [4, 6, 3, 4, 5, 8, 4, 2]

# %%
import numpy as np

valor_maximo = np.max(valores)
valor_minimo = np.min(valores)
media = np.mean(valores)
mediana = np.median(valores)
desvio_padrao = np.std(valores)

res = print(f"Valor máximo: '{valor_maximo}', Valor mínimo: '{valor_minimo}', Média: '{media}', Mediana: '{mediana}', Desvio padrão: '{desvio_padrao}'")
# Out:
# Valor máximo: '8', Valor mínimo: '2', Média: '4.5', Mediana: '4.0', Desvio padrão: '1.7320508075688772'
