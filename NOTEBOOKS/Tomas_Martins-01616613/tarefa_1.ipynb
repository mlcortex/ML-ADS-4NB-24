# %% [markdown]
# # **Tarefa 1 - Machine learning**

# %% [markdown]
# Aluno: Marcello José Menezes de Medeiros Filho
#
# Mat: 01345111
#
# Turma: 4NB

# %%
import pandas as pd

# %% [markdown]
# ### **Valores**

# %%
dados = {'alunos': ["Marcello", "Alex", "Vitor", "Claudio", "Kayk", "Gabriel", "Buzz", "Cleiton"],'notas': [4, 6, 3, 4, 5, 8, 4, 2]}
df = pd.DataFrame(dados)

# %%
df
# Out:
#      alunos  notas
# 0  Marcello      4
# 1      Alex      6
# 2     Vitor      3
# 3   Claudio      4
# 4      Kayk      5
# 5   Gabriel      8
# 6      Buzz      4
# 7   Cleiton      2

# %% [markdown]
# ### **1. Valor Máximo**

# %%
max = df['notas'].max()
print("O valor máximo é:", max)
# Out:
# O valor máximo é: 8

# %% [markdown]
# ### **2. Valor Mínimo**

# %%
min = df['notas'].min()
print("O valor mínimo é:", min)
# Out:
# O valor mínimo é: 2

# %% [markdown]
# ### **3. Média**

# %%
media = df['notas'].mean()
print("A média é:", media)
# Out:
# A média é: 4.5

# %% [markdown]
# ### **4. Mediana**

# %%
mediana = df['notas'].median()
print("A média é:", mediana)
# Out:
# A média é: 4.0

# %% [markdown]
# ### **5. Desvio padrão**

# %%
desvio_padrao = df['notas'].std()
print("O desvio padrão é:", desvio_padrao)
# Out:
# O desvio padrão é: 1.8516401995451028
