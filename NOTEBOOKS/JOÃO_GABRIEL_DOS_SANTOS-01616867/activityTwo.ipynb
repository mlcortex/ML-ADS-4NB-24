# %%
import pandas as pd

# URL do dataset Wine
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

# Nome das colunas em português BR
column_names_pt_br = [
    'classe',
    'alcool',
    'acido_malico',
    'cinzas',
    'alcalinidade_de_cinzas',
    'magnesio',
    'fenois_totais',
    'flavanoides',
    'fenois_nao_flavanoides',
    'proantocianinas',
    'intensidade_de_cor',
    'matiz',
    'od280_od315_de_vinhos_diluidos',
    'prolina'
]

# Ler o arquivo CSV com as colunas especificadas, definindo a coluna 'classe' como object
vinhos = pd.read_csv(url, names=column_names_pt_br, dtype={'classe': object})

# %% [markdown]
# # **1. Análise Exploratória de Variáveis**
# classe: Faça a contagem das diferentes classes presentes no dataset.

# %%
vinhos.head(5)
# Out:
#   classe  alcool  acido_malico  cinzas  alcalinidade_de_cinzas  magnesio  \
# 0      1   14.23          1.71    2.43                    15.6       127
# 1      1   13.20          1.78    2.14                    11.2       100
# 2      1   13.16          2.36    2.67                    18.6       101
# 3      1   14.37          1.95    2.50                    16.8       113
# 4      1   13.24          2.59    2.87                    21.0       118
#
#    fenois_totais  flavanoides  fenois_nao_flavanoides  proantocianinas  \
# 0           2.80         3.06                    0.28             2.29
# 1           2.65         2.76                    0.26             1.28
# 2           2.80         3.24                    0.30             2.81
# 3           3.85         3.49                    0.24             2.18
# 4           2.80         2.69                    0.39             1.82
#
#    intensidade_de_cor  matiz  od280_od315_de_vinhos_diluidos  prolina
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visão geral do DataFrame
print(vinhos.describe())

vinhos.groupby('classe').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
#            alcool  acido_malico      cinzas  alcalinidade_de_cinzas  \
# count  178.000000    178.000000  178.000000              178.000000
# mean    13.000618      2.336348    2.366517               19.494944
# std      0.811827      1.117146    0.274344                3.339564
# min     11.030000      0.740000    1.360000               10.600000
# 25%     12.362500      1.602500    2.210000               17.200000
# 50%     13.050000      1.865000    2.360000               19.500000
# 75%     13.677500      3.082500    2.557500               21.500000
# max     14.830000      5.800000    3.230000               30.000000
#
#          magnesio  fenois_totais  flavanoides  fenois_nao_flavanoides  \
# count  178.000000     178.000000   178.000000              178.000000
# mean    99.741573       2.295112     2.029270                0.361854
# std     14.282484       0.625851     0.998859                0.124453
# min     70.000000       0.980000     0.340000                0.130000
# ...

# %%
# Contagem de valores únicos na coluna classe
print(vinhos['classe'].value_counts())

# %% [markdown]
# #**Alcool**

# %%
#Descrição do alcool
describeAlcool = vinhos['alcool'].describe()
print(describeAlcool)
# Out:
# count    178.000000
# mean      13.000618
# std        0.811827
# min       11.030000
# 25%       12.362500
# 50%       13.050000
# 75%       13.677500
# max       14.830000
# Name: alcool, dtype: float64

# %% [markdown]
# #**Acido** **Malico**

# %%
#Descrição do acido malico
describeMalico = vinhos['acido_malico'].describe()
print(describeMalico)
# Out:
# count    178.000000
# mean       2.336348
# std        1.117146
# min        0.740000
# 25%        1.602500
# 50%        1.865000
# 75%        3.082500
# max        5.800000
# Name: acido_malico, dtype: float64

# %% [markdown]
# #**Magnesio**

# %%
#Descrição do Magnesio
describeMagnesio = vinhos['acido_malico'].describe()
print(describeMagnesio)
# Out:
# count    178.000000
# mean       2.336348
# std        1.117146
# min        0.740000
# 25%        1.602500
# 50%        1.865000
# 75%        3.082500
# max        5.800000
# Name: acido_malico, dtype: float64

# %% [markdown]
# #**Matiz**

# %%
#Descrição do Matriz
describeMatiz = vinhos['matiz'].describe()
print(describeMatiz)
# Out:
# count    178.000000
# mean       0.957449
# std        0.228572
# min        0.480000
# 25%        0.782500
# 50%        0.965000
# 75%        1.120000
# max        1.710000
# Name: matiz, dtype: float64

# %% [markdown]
# #**2. Criação de Boxplots**

# %% [markdown]
# **Magnesio**

# %%
# Criação do boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='magnesio', data=vinhos)
plt.title('Boxplot de Magnésio')
plt.xlabel('Magnésio')
plt.show()

# %% [markdown]
# **Prolina**

# %%
# Criação do boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='prolina', data=vinhos)
plt.title('Boxplot de Prolina')
plt.xlabel('Prolina')
plt.show()

# %% [markdown]
# **Cinzas**

# %%
# Criação do boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='cinzas', data=vinhos)
plt.title('Boxplot de Cinzas')
plt.xlabel('Cinzas')
plt.show()

# %% [markdown]
# **Alcool**

# %%
# Criação do boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='alcool', data=vinhos)
plt.title('Boxplot de Alcool')
plt.xlabel('Alcool')
plt.show()

# %% [markdown]
# 3. Boxplots Segregados por Classe

# %% [markdown]
# **Magnesio**

# %%
# Criação do boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='classe', y='magnesio', data=vinhos)
plt.title('Boxplot de Magnésio por Classe')
plt.xlabel('Classe')
plt.ylabel('Magnésio')
plt.show()

# %% [markdown]
# **Fenois**

# %%
# Criação do boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='classe', y='fenois_totais', data=vinhos)
plt.title('Boxplot de Fenois por Classe')
plt.xlabel('Classe')
plt.ylabel('Fenois')
plt.show()

# %% [markdown]
# **Acido Malico**

# %%
# Criação do boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='classe', y='acido_malico', data=vinhos)
plt.title('Boxplot de Malico por Classe')
plt.xlabel('Classe')
plt.ylabel('Malico')
plt.show()

# %% [markdown]
# **Alcool**

# %%
# Criação do boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='classe', y='alcool', data=vinhos)
plt.title('Boxplot de Alcool por Classe')
plt.xlabel('Classe')
plt.ylabel('Alcool')
plt.show()

# %% [markdown]
# #**4. Criação de Histograma**

# %% [markdown]
# Crie um histograma para visualizar a distribuição dos dados na coluna:
# fenois_totais, utilizando 10 bins
#
# Dica: Utilize plt.hist() ou sns.histplot() para criar histogramas e ajuste o número de bins usando o argumento bins=10.

# %%
# Visualização da distribuição dos dados Fenois

plt.figure(figsize=(10, 6))
plt.hist(vinhos['fenois_totais'], bins=10)
plt.title('Histograma de Fenois Totais')
plt.xlabel('Fenois Totais')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# Classe 3

# %%
# Visualização da coluna fenois_totais, filtrando apenas a classe 3, utilizando 10 bins.

vinhos_classe_3 = vinhos[vinhos['classe'] == '3']

plt.figure(figsize=(10, 6))
plt.hist(vinhos_classe_3['fenois_totais'], bins=10)
plt.title('Histograma de Fenois Totais (Classe 3)')
plt.xlabel('Fenois Totais')
plt.ylabel('Frequência')
plt.show()
