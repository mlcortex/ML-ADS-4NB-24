# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# URL do dataset Wine
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

# Nome das colunas em português BR
column_names_pt_br = [
    'classe',
    'alcool',
    'acido_malico',
    'cinzas',
    'alcalinidade_de_cinzas',
    'magnesio',
    'fenois_totais',
    'flavanoides',
    'fenois_nao_flavanoides',
    'proantocianinas',
    'intensidade_de_cor',
    'matiz',
    'od280_od315_de_vinhos_diluidos',
    'prolina'
]

# Ler o arquivo CSV com as colunas especificadas, definindo a coluna 'classe' como object
vinhos = pd.read_csv(url, names=column_names_pt_br, dtype={'classe': object})
vinhos
# Out:
#     classe  alcool  acido_malico  cinzas  alcalinidade_de_cinzas  magnesio  \
# 0        1   14.23          1.71    2.43                    15.6       127
# 1        1   13.20          1.78    2.14                    11.2       100
# 2        1   13.16          2.36    2.67                    18.6       101
# 3        1   14.37          1.95    2.50                    16.8       113
# 4        1   13.24          2.59    2.87                    21.0       118
# ..     ...     ...           ...     ...                     ...       ...
# 173      3   13.71          5.65    2.45                    20.5        95
# 174      3   13.40          3.91    2.48                    23.0       102
# 175      3   13.27          4.28    2.26                    20.0       120
# 176      3   13.17          2.59    2.37                    20.0       120
# 177      3   14.13          4.10    2.74                    24.5        96
#
# ...

# %%
vinhos.describe()
# estatística descritiva de vinhos
# Out:
#            alcool  acido_malico      cinzas  alcalinidade_de_cinzas  \
# count  178.000000    178.000000  178.000000              178.000000
# mean    13.000618      2.336348    2.366517               19.494944
# std      0.811827      1.117146    0.274344                3.339564
# min     11.030000      0.740000    1.360000               10.600000
# 25%     12.362500      1.602500    2.210000               17.200000
# 50%     13.050000      1.865000    2.360000               19.500000
# 75%     13.677500      3.082500    2.557500               21.500000
# max     14.830000      5.800000    3.230000               30.000000
#
#          magnesio  fenois_totais  flavanoides  fenois_nao_flavanoides  \
# count  178.000000     178.000000   178.000000              178.000000
# mean    99.741573       2.295112     2.029270                0.361854
# std     14.282484       0.625851     0.998859                0.124453
# min     70.000000       0.980000     0.340000                0.130000
# ...

# %%
vinhos['classe'].value_counts()
# valores únicos na coluna classe
# Out:
# classe
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='magnesio', data=vinhos)
plt.title('Boxplot da coluna Magnesio')
plt.show()
#boxplot da coluna magnesio

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='prolina', data=vinhos)
plt.title('Boxplot da coluna Prolina')
plt.show()
#boxplot da coluna Prolina

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='cinzas', data=vinhos)
plt.title('Boxplot da coluna Cinzas')
plt.show()
#boxplot da coluna cinza

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='alcool', data=vinhos)
plt.title('Boxplot da coluna Alcool')
plt.show()
#boxplot da coluna alcoll

# %%
vinhos.boxplot(column='magnesio', by='classe')
# Out:
# <Axes: title={'center': 'magnesio'}, xlabel='classe'>

# %%
vinhos.boxplot(column='fenois_totais', by='classe')
# Out:
# <Axes: title={'center': 'fenois_totais'}, xlabel='classe'>

# %%
vinhos.boxplot(column='acido_malico', by='classe')
# Out:
# <Axes: title={'center': 'acido_malico'}, xlabel='classe'>

# %%
vinhos.boxplot(column='alcool', by='classe')
# Out:
# <Axes: title={'center': 'alcool'}, xlabel='classe'>

# %%
plt.figure(figsize=(8, 6))
plt.hist(vinhos['fenois_totais'], bins=10)
plt.xlabel('Fenois Totais')
plt.ylabel('Frequência')
plt.title('Histograma da coluna Fenois Totais')
plt.show()

# %%
vinhos_classe_3 = vinhos[vinhos['classe'] == '3']

# %%
plt.figure(figsize=(8, 6))
plt.hist(vinhos_classe_3['fenois_totais'], bins=10)
plt.xlabel('Fenois Totais')
plt.ylabel('Frequência')
plt.title('Histograma da coluna Fenois Totais (Classe 3)')
plt.show()
