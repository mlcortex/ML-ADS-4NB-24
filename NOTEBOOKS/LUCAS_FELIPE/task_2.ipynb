# %%
import pandas as pd

# URL do dataset Wine
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

# Nome das colunas em português BR
column_names_pt_br = [
    'classe',
    'alcool',
    'acido_malico',
    'cinzas',
    'alcalinidade_de_cinzas',
    'magnesio',
    'fenois_totais',
    'flavanoides',
    'fenois_nao_flavanoides',
    'proantocianinas',
    'intensidade_de_cor',
    'matiz',
    'od280_od315_de_vinhos_diluidos',
    'prolina'
]

# Ler o arquivo CSV com as colunas especificadas, definindo a coluna 'classe' como object
vinhos = pd.read_csv(url, names=column_names_pt_br, dtype={'classe': object})

# %%
vinhos.value_counts()
# Out:
# classe  alcool  acido_malico  cinzas  alcalinidade_de_cinzas  magnesio  fenois_totais  flavanoides  fenois_nao_flavanoides  proantocianinas  intensidade_de_cor  matiz  od280_od315_de_vinhos_diluidos  prolina
# 1       12.85   1.60          2.52    17.8                    95        2.48           2.37         0.26                    1.46             3.93                1.09   3.63                            1015       1
# 3       12.36   3.83          2.38    21.0                    88        2.30           0.92         0.50                    1.04             7.65                0.56   1.58                            520        1
# 2       12.60   1.34          1.90    18.5                    88        1.45           1.36         0.29                    1.35             2.45                1.04   2.77                            562        1
# ...

# %%
vinhos['matiz'].describe()
# Out:
# count    178.000000
# mean       0.957449
# std        0.228572
# min        0.480000
# 25%        0.782500
# 50%        0.965000
# 75%        1.120000
# max        1.710000
# Name: matiz, dtype: float64

# %%
vinhos['magnesio'].describe()
# Out:
# count    178.000000
# mean      99.741573
# std       14.282484
# min       70.000000
# 25%       88.000000
# 50%       98.000000
# 75%      107.000000
# max      162.000000
# Name: magnesio, dtype: float64

# %%
vinhos['acido_malico'].describe()
# Out:
# count    178.000000
# mean       2.336348
# std        1.117146
# min        0.740000
# 25%        1.602500
# 50%        1.865000
# 75%        3.082500
# max        5.800000
# Name: acido_malico, dtype: float64

# %%
vinhos['alcool'].describe()
# Out:
# count    178.000000
# mean      13.000618
# std        0.811827
# min       11.030000
# 25%       12.362500
# 50%       13.050000
# 75%       13.677500
# max       14.830000
# Name: alcool, dtype: float64

# %%
#boxplots da dispersão dos dados das colunas
#magnesio
#prolina
#cinzas
#alcool

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.boxplot(data=vinhos, y='magnesio')
plt.title('Dispersão de Magnésio')

plt.subplot(2, 2, 2)
sns.boxplot(data=vinhos, y='prolina')
plt.title('Dispersão de Prolina')

plt.subplot(2, 2, 3)
sns.boxplot(data=vinhos, y='cinzas')
plt.title('Dispersão de Cinzas')

plt.subplot(2, 2, 4)
sns.boxplot(data=vinhos, y='alcool')
plt.title('Dispersão de Álcool')

plt.tight_layout()

plt.show()

# %%
#boxplots das colunas
#magnesio
#fenois_totais
#acido_malico
#alcool

plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
vinhos.boxplot(column='magnesio', by='classe')
plt.title('Boxplot de Magnésio por Classe')
plt.suptitle('')

plt.subplot(2, 2, 2)
vinhos.boxplot(column='fenois_totais', by='classe')
plt.title('Boxplot de Fenois Totais por Classe')
plt.suptitle('')

plt.subplot(2, 2, 3)
vinhos.boxplot(column='acido_malico', by='classe')
plt.title('Boxplot de Ácido Málico por Classe')
plt.suptitle('')

plt.subplot(2, 2, 4)
vinhos.boxplot(column='alcool', by='classe')
plt.title('Boxplot de Álcool por Classe')
plt.suptitle('')

plt.tight_layout()

plt.show()
# Out:
# <ipython-input-11-1dcb62180124>:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 2)
# <ipython-input-11-1dcb62180124>:13: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 3)
# <ipython-input-11-1dcb62180124>:18: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 4)

# %%
#dados da coluna fenois totais
plt.hist(vinhos['fenois_totais'], bins=10)
plt.xlabel('Fenois Totais')
plt.ylabel('Frequência')
plt.title('Histograma de Fenois Totais')
plt.show()

# %%
# Filtrar os dados para a classe 3
vinhos_classe_3 = vinhos[vinhos['classe'] == '3']

plt.hist(vinhos_classe_3['fenois_totais'], bins=10)
plt.xlabel('Fenois Totais')
plt.ylabel('Frequência')
plt.title('Histograma de Fenois Totais (Classe 3)')
plt.show()
